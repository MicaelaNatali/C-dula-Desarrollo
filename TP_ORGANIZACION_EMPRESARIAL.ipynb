# %% [markdown]
# <a href="https://colab.research.google.com/github/MicaelaNatali/Cedula-Desarrollo/blob/main/TP_ORGANIZACION_EMPRESARIAL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/MicaelaNatali/Cedula-Desarrollo.git
# Out:
# Cloning into 'Cedula-Desarrollo'...
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
# %cd /content/Cedula-Desarrollo
# !git status
# Out:
# /content/Cedula-Desarrollo
# On branch main
# Your branch is ahead of 'origin/main' by 1 commit.
#   (use "git push" to publish your local commits)
#
# nothing to commit, working tree clean

# %%
# %cd /content/Cedula-Desarrollo
# !git push
# Out:
# /content/Cedula-Desarrollo
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
# !git config --global user.email "micaelanatali09@gmail.com"
# !git config --global user.name "Micaela Natali Villanueva"

# %%
# !git config --global user.name
# !git config --global user.email
# Out:
# Micaela Natali Villanueva
# micaelanatali09@gmail.com

# %%
# %cd /content/Cedula-Desarrollo

# !git status
# Out:
# /content/Cedula-Desarrollo
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
# %cd /content/Cedula-Desarrollo
# !mkdir -p scripts
# Out:
# /content/Cedula-Desarrollo

# %%
# %%writefile scripts/analisis.py
print("TP Organización Empresarial")
print("Análisis ejecutado correctamente"
# Out:
# Writing scripts/analisis.py

# %%
# %cd /content/Cedula-Desarrollo
# !mkdir -p scripts
# %%writefile scripts/analisis.py
print("TP Organización Empresarial")
print("Análisis ejecutado correctamente")
# Out:
# /content/Cedula-Desarrollo
# UsageError: Line magic function `%%writefile` not found.

# %%
# %cd /content/Cedula-Desarrollo
# !mkdir -p scripts
# Out:
# /content/Cedula-Desarrollo

# %%
# %%writefile scripts/analisis.py
print("TP Organización Empresarial")
print("Análisis ejecutado correctamente")
# Out:
# Overwriting scripts/analisis.py

# %%
# %cd /content/Cedula-Desarrollo
# !git status
# !ls scripts
# Out:
# /content/Cedula-Desarrollo
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	scripts/
#
# nothing added to commit but untracked files present (use "git add" to track)
# analisis.py

# %%
# %cd /content/Cedula-Desarrollo
# !ls scripts
# Out:
# /content/Cedula-Desarrollo
# analisis.py

# %%
# %cd /content/Cedula-Desarrollo
# !git add .
# !git commit -m "Agrego scripts y analisis"
# Out:
# /content/Cedula-Desarrollo
# Author identity unknown
#
# *** Please tell me who you are.
#
# Run
#
#   git config --global user.email "you@example.com"
#   git config --global user.name "Your Name"
#
# to set your account's default identity.
# Omit --global to set the identity only in this repository.
#
# fatal: unable to auto-detect email address (got 'root@db4a0b99b784.(none)')

# %%
# !git config --global user.name "MicaelaNatali"
# !git config --global user.email "micaelanatali09@gmail.com"

# %%
# %cd /content/Cedula-Desarrollo
# !git add .
# !git commit -m "Agrego scripts y analisis"
# Out:
# /content/Cedula-Desarrollo
# [main aa5bd98] Agrego scripts y analisis
#  1 file changed, 2 insertions(+)
#  create mode 100644 scripts/analisis.py

# %%
Writing scripts/analisis.py
# Out:
#   File "/tmp/ipykernel_9617/1418163923.py", line 1
#     Writing scripts/analisis.py
#             ^
# SyntaxError: invalid syntax

# %%
# %cd /content/Cedula-Desarrollo
# !ls
# Out:
# [Errno 2] No such file or directory: '/content/Cedula-Desarrollo'
# /content
# sample_data

# %%
# %cd /content
# !git clone https://github.com/MicaelaNatali/Cedula-Desarrollo.git
# %cd /content/Cedula-Desarrollo
# !ls
# Out:
# /content
# Cloning into 'Cedula-Desarrollo'...
# remote: Enumerating objects: 15, done.
# remote: Counting objects: 100% (15/15), done.
# remote: Compressing objects: 100% (11/11), done.
# remote: Total 15 (delta 4), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (15/15), 4.24 KiB | 2.12 MiB/s, done.
# Resolving deltas: 100% (4/4), done.
# /content/Cedula-Desarrollo
# README.md  TP_ORGANIZACION_EMPRESARIAL.ipynb

# %%
# %cd /content/Cedula-Desarrollo
# !mkdir -p scripts
# Out:
# /content/Cedula-Desarrollo

# %%
# %%writefile scripts/analisis.py
print("TP Organización Empresarial")
print("Análisis ejecutado correctamente")
# Out:
# Writing scripts/analisis.py

# %%
# !git add .
# !git commit -m "Agrego scripts y analisis"
# Out:
# Author identity unknown
#
# *** Please tell me who you are.
#
# Run
#
#   git config --global user.email "you@example.com"
#   git config --global user.name "Your Name"
#
# to set your account's default identity.
# Omit --global to set the identity only in this repository.
#
# fatal: unable to auto-detect email address (got 'root@b749f5906b13.(none)')

# %%
# !git config --global user.name "MicaelaNatali"
# !git config --global user.email "micaelanatali09@gmail.com
# Out:
# /bin/bash: -c: line 1: unexpected EOF while looking for matching `"'
# /bin/bash: -c: line 2: syntax error: unexpected end of file

# %%
# !git config --global user.name "MicaelaNatali"
# !git config --global user.email "micaelanatali09@gmail.com"

# %%
# %cd /content/Cedula-Desarrollo
# !git add .
# !git commit -m "Agrego scripts y analisis"
# Out:
# [Errno 2] No such file or directory: '/content/Cedula-Desarrollo'
# /content
# fatal: not a git repository (or any of the parent directories): .git
# fatal: not a git repository (or any of the parent directories): .git

# %%
# %cd /content
# !git clone https://github.com/MicaelaNatali/Cedula-Desarrollo.git
# %cd /content/Cedula-Desarrollo
# !git push
# Out:
# /content
# Cloning into 'Cedula-Desarrollo'...
# remote: Enumerating objects: 15, done.
# remote: Counting objects: 100% (15/15), done.
# remote: Compressing objects: 100% (11/11), done.
# remote: Total 15 (delta 4), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (15/15), 4.24 KiB | 4.24 MiB/s, done.
# Resolving deltas: 100% (4/4), done.
# /content/Cedula-Desarrollo
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
# %cd /content
# !rm -rf Cedula-Desarrollo
# !git clone https://github.com/MicaelaNatali/C-dula-Desarrollo.git
# Out:
# /content
# fatal: destination path 'C-dula-Desarrollo' already exists and is not an empty directory.

# %%
# %cd /content
# !rm -rf C-dula-Desarrollo
# !git clone https://github.com/MicaelaNatali/Cedula-Desarrollo.git
# %cd /content/Cedula-Desarrollo
# !pwd
# !ls
# Out:
# /content
# Cloning into 'Cedula-Desarrollo'...
# remote: Enumerating objects: 9, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 9 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (9/9), done.
# /content/Cedula-Desarrollo
# /content/Cedula-Desarrollo
# README.md  TP_ORGANIZACION_EMPRESARIAL.ipynb

# %%
# %cd /content/Cedula-Desarrollo
# !git add .
# !git commit -m "Subo scripts y estructura"
# Out:
# /content/Cedula-Desarrollo
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
# %cd /content/Cedula-Desarrollo
# !mkdir scripts
# %%writefile scripts/analisis.py
print("TP Organización Empresarial")
print("Análisis ejecutado correctamente")
# Out:
# /content/Cedula-Desarrollo
# UsageError: Line magic function `%%writefile` not found.

# %%
# %cd /content/Cedula-Desarrollo
# !mkdir -p scripts
# Out:
# /content/Cedula-Desarrollo

# %%
# %%writefile scripts/analisis.py
print("TP Organización Empresarial")
print("Análisis ejecutado correctamente")
# Out:
# Writing scripts/analisis.py

# %%
# !git add .
# !git commit -m "Agrego scripts y analisis"
# Out:
# [main cdb077b] Agrego scripts y analisis
#  1 file changed, 2 insertions(+)
#  create mode 100644 scripts/analisis.py

# %%
# %cd /content/Cedula-Desarrollo
# !git push
# Out:
# /content/Cedula-Desarrollo
# fatal: could not read Username for 'https://github.com': No such device or address
