# %% [markdown]
# <a href="https://colab.research.google.com/github/MicaelaNatali/C-dula-Desarrollo/blob/main/TP_ORGANIZACION_EMPRESARIAL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/MicaelaNatali/Cedula-Desarrollo.git
# Out:
# Cloning into 'Cedula-Desarrollo'...
# fatal: could not read Username for 'https://github.com': No such device or address
